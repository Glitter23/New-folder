# %%
import pandas as pd

# %%
df=pd.read_excel(r'C:\Users\Rashmi\Desktop\datafile.xls')
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
df.shape
# Out:
# (73, 16)

# %%
df.head
# Out:
# <bound method NDFrame.head of     Commodities Country of Origin  SMP (KDS)  SMP(HDC)  PPT  VPT  KPL  ChPT  \
# 0   POL-PRODUCT         Australia          0         0    0    0    0     0
# 1   POL-PRODUCT         Argentina          0         0    0    0    0     0
# 2   POL-PRODUCT        Bangladesh          0         0   70    0    0     0
# 3   POL-PRODUCT             China          0        30   20  330    0   144
# 4   POL-PRODUCT             Egypt          0         0    0    0    0     0
# ..          ...               ...        ...       ...  ...  ...  ...   ...
# 68   OTHER ORES       Netherlands          0         0    0    0    0     0
# 69   OTHER ORES             Qatar          0         0    0   15    0     0
# 70   OTHER ORES      Saudi Arabia          0         0    0    0    0     0
# 71   OTHER ORES   Other Countries          0         0  287    0    0   602
# 72   OTHER ORES             Total          0         0  372   85    0   602
#
# ...

# %%
df.describe()
# Out:
#        SMP (KDS)     SMP(HDC)           PPT          VPT   KPL         ChPT  \
# count  73.000000    73.000000     73.000000    73.000000  73.0    73.000000
# mean    1.301370   114.821918    481.698630   173.438356   0.0    84.876712
# std     7.642507   489.688374   2473.354485   663.203442   0.0   247.748133
# min     0.000000     0.000000      0.000000     0.000000   0.0     0.000000
# 25%     0.000000     0.000000      0.000000     0.000000   0.0     0.000000
# 50%     0.000000     0.000000      0.000000     0.000000   0.0     0.000000
# 75%     0.000000    10.000000     28.000000    21.000000   0.0     0.000000
# max    47.000000  2937.000000  15645.000000  4829.000000   0.0  1460.000000
#
#             V.O.C         CoPT         NMPT         MoPT        JNPT  \
# count   73.000000    73.000000    73.000000    73.000000   73.000000
# mean     4.246575    30.452055   175.356164    40.876712   12.095890
# std     20.800495   149.876990   583.030216   228.577664   55.535565
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Commodities', 'Country of Origin', 'SMP (KDS)', 'SMP(HDC)', 'PPT',
#        'VPT', 'KPL', 'ChPT', 'V.O.C', 'CoPT', 'NMPT', 'MoPT', 'JNPT', 'MbPT',
#        'DPT', 'ALL PORTS'],
#       dtype='object')

# %%
df[df['Country of Origin']=='Australia']
# Out:
#    Commodities Country of Origin  SMP (KDS)  SMP(HDC)  PPT  VPT  KPL  ChPT  \
# 0  POL-PRODUCT         Australia          0         0    0    0    0     0
#
#    V.O.C  CoPT  NMPT  MoPT  JNPT  MbPT  DPT  ALL PORTS
# 0      0     0     0     0     0     0  162        162

# %%
z=df['Country of Origin'].unique()

# %%
for i in z:
    df[df['Country of Origin']==i]

# %%
df1=df[['Commodities','Country of Origin','ALL PORTS']]

# %%
df1
# Out:
#     Commodities Country of Origin  ALL PORTS
# 0   POL-PRODUCT         Australia        162
# 1   POL-PRODUCT         Argentina        106
# 2   POL-PRODUCT        Bangladesh        210
# 3   POL-PRODUCT             China       1481
# 4   POL-PRODUCT             Egypt        387
# ..          ...               ...        ...
# 68   OTHER ORES       Netherlands         44
# 69   OTHER ORES             Qatar         16
# 70   OTHER ORES      Saudi Arabia         34
# 71   OTHER ORES   Other Countries        969
# 72   OTHER ORES             Total       1364
#
# [73 rows x 3 columns]

# %%
plt.pie(df['ALL PORTS'],labels=df['Country of Origin'])
# Out:
# ([<matplotlib.patches.Wedge at 0x29938752e50>,
# ...
#  [Text(1.0999877958811535, 0.005181593627652802, 'Australia'),
#   Text(1.0999140178208735, 0.013753305098889614, 'Argentina'),
#   Text(1.0997412157596456, 0.02385913576592429, 'Bangladesh'),
#   Text(1.0972393806738476, 0.07788287037899672, 'China'),
#   Text(1.0913929101300834, 0.1373372335449783, 'Egypt'),
#   Text(1.0895024904317887, 0.15160581566328568, 'France'),
#   Text(1.0889125683145955, 0.1557864518066691, 'Indonesia'),
#   Text(1.085417851437022, 0.17851635158113338, 'Japan'),
#   Text(1.0777170268170868, 0.22028620044963967, 'Jordan'),
#   Text(1.0727137770999344, 0.24348542547756782, 'Kenya'),
#   Text(1.0662824119219843, 0.27026249837118693, 'South Korea'),
#   Text(1.042945916393137, 0.3496624307512605, 'Malaysia'),
#   Text(1.0185564745541174, 0.41538260452730574, 'Mauritius'),
#   Text(1.0046344333014208, 0.44800631181394457, 'Netherland'),
#   Text(0.9904483552117728, 0.4785520407001668, 'Oman'),
# ...
